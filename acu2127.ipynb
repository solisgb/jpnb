# %% [markdown]
# ## balances acuiferos en DHS

# %%
import pandas as pd

# %%
fmasub = r'E:\off\phdhs2127\H2OG\20200924_balances_masub\balances_masub_21-27_v005.xlsm'
sheet_masub = 'balan_masub21-27'
skiprows=1
usecols01 = 'A:B,M:X'
converters = {'masa_id': str}

# %%
dfmasub2127 = pd.read_excel(fmasub, sheet_name=sheet_masub, skiprows=skiprows, usecols=usecols01,
                            converters=converters, engine='openpyxl')

# %%
dfmasu1acu = dfmasub2127[dfmasub2127["Num acu.1"]==1]

# %%
dfmasu1acu.head(10)
# Out:
#     masa_id                                   masa_nombre  Num acu.1  \
# 0   070.001                                  CORRAL RUBIO          1
# 1   070.002                       SINCLINAL DE LA HIGUERA          1
# 4   070.005                        TOBARRA-TEDERA-PINILLA          1
# 5   070.006                                          PINO          1
# 6   070.007                            CONEJEROS-ALBATANA          1
# 8   070.009                            SIERRA DE LA OLIVA          1
# 12  070.013                                     MORATILLA          1
# 13  070.014                               CALAR DEL MUNDO          1
# 16  070.017  ACUÍFEROS INFERIORES DE LA SIERRA DEL SEGURA          1
# 17  070.018                                       MACHADA          1
#
#     e_lluvia.1  e_retornos_riego.1  e_sub.1  e_cauce.1  contador  s_bombeos.1  \
# 0         2.00                0.10     1.20        0.0      0.07         3.30
# ...
