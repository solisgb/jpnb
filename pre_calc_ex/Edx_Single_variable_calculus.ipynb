# %% [markdown]
# # Single variable calculus

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#def f(x):
#    return (x**2 - 4)/(x**2 - 3*x -4)

# %%
for x in (3, 2.5, 2.1, 2.001, 2.00001):
    print(f(x))
# Out:
# -1.25
# -0.42857142857142855
# -0.06960950764006793
# -0.0006669446019243709
# -6.666694444646906e-06

# %%
y = (-.51, -1.48, 0.16, -0.26, -0.25, -0.17, -0.24, 0.29, 0.11)
x = (-3., -2.25, -1.5, -0.75, 0, 0.75, 1.5, 2.25, 3)

# %%
len(y)
# Out:
# 9

# %%
plt.plot(x,y)
plt.axhline(y=0.0, color='k', linestyle='-')
plt.axvline(x=0.0, color='k', linestyle='-')
for x1, y1 in zip(x, y): 
    plt.text(x1, y1, f'{str(x1)}\n{str(y1)}')
plt.show()

# %%
0/17
# Out:
# 0.0
